# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error , mean_squared_error ,r2_score

df = pd.read_csv('../data/student_exam_scores.csv',usecols=['hours_studied','exam_score'])
df.head()

X = df[['hours_studied']]
y=df['exam_score']

model = LinearRegression()
model.fit(X,y)

predicted_score = model.predict(X)

#evaluation matrix
mae = mean_absolute_error(y , predicted_score)
mse = mean_squared_error(y , predicted_score)
rmse = np.sqrt(mse)
print(mae,mse,rmse)

new_hrs = [[5]]
new_pred =  model.predict(new_hrs)
print("R² Score:", r2_score(y,predicted_score))
print(f"prediction for {new_hrs} is {new_pred} ")
# Out:
# 3.477804979297655 18.193664583349367 4.265403214626885
# R² Score: 0.6033427917418744
# prediction for [[5]] is [31.78898733]
# d:\Machine Learing\venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
df = pd.read_csv("../data/student_exam_scores.csv",usecols=['hours_studied','previous_scores']).head(10)
X = df[['hours_studied']]
y=df['previous_scores']
plt.figure(figsize=(10,6))
plt.scatter(X,y)

model = LinearRegression()
model.fit(X,y)

predicted_future_score = model.predict(X)

studied_hrs = pd.DataFrame([[5],[8]],columns=['hours_studied'])
pred_future_score = model.predict(studied_hrs)
print(f"pred_future_score : {pred_future_score}")
plt.scatter(studied_hrs,pred_future_score)
# Out:
# pred_future_score : [68.9464351  73.09817185]

# %%
df = pd.read_csv('../data/student_exam_scores.csv',usecols=['hours_studied','previous_scores','exam_score']).head()


X=df[['hours_studied']]
y= df['previous_scores']-df['exam_score']
plt.figure(figsize=(8,6))
plt.scatter(X['hours_studied'], y)


ln = LinearRegression()
ln.fit(X,y)
studied_hrs = pd.DataFrame([[5],[8]],columns=['hours_studied'])

predicted_future_exam_score = ln.predict(studied_hrs)
print(f"pred_exam_score : {predicted_future_exam_score}")


plt.scatter(studied_hrs,predicted_future_exam_score)
# Out:
# pred_exam_score : [31.82451395 27.08261482]
